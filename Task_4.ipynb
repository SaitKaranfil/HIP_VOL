# %%
import numpy as  np
import pandas as pd
import seaborn as sbn
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("Temporary_data3_-_Copy.xlsx")

# %%
data=pd.DataFrame(data)

# %%
data.head()
# Out:
#    SEX  EDUC  MARISTAT  INDEPEND  RESIDENC  NACCFAM  ANYMEDS  SMOKYRS  \
# 0    2    18         1         1         1        1        1        0
# 1    1    11         1         1         1        1        1        0
# 2    2    16         1         1         1        1        1       10
# 3    1    14         1         1         1        0        1        0
# 4    1    16         1         1         2        0        1       50
#
#    NACCTBI  DIABETES  ...   RSUPFR  RSUPFRM  RSUPPAR  RSUPPARM  RSUPTEM  \
# 0        0         0  ...  27.9038   2.2157  10.3481    1.7014  13.4250
# 1        0         0  ...  29.0600   2.6900   9.2500    1.6300  14.8800
# 2        0         1  ...  33.0000   2.5400  13.6900    1.5600  16.2300
# 3        0         1  ...  31.6800   2.4100   9.6400    1.4500  15.1100
# 4        0         0  ...  28.0631   1.9501   9.1125    1.0427  13.3763
#
#    RSUPTEMM  RSUPMAR  RSUPMARM  RTRTEM  RTRTEMM
# 0    1.7419   9.8700    1.6792  0.8906   1.1947
# ...

# %% [markdown]
# TASK-4A: Please present a descriptive statistics analysis to provide a general understanding of the dataset

# %%
data.describe()
# Out:
#                SEX         EDUC     MARISTAT     INDEPEND     RESIDENC  \
# count  1354.000000  1354.000000  1354.000000  1354.000000  1354.000000
# mean      1.573855    15.223781     1.658789     1.316100     1.112999
# std       0.494698     3.418699     1.136754     0.598538     0.360372
# min       1.000000     0.000000     1.000000     1.000000     1.000000
# 25%       1.000000    12.000000     1.000000     1.000000     1.000000
# 50%       2.000000    16.000000     1.000000     1.000000     1.000000
# 75%       2.000000    18.000000     2.000000     2.000000     1.000000
# max       2.000000    25.000000     6.000000     4.000000     4.000000
#
#            NACCFAM      ANYMEDS      SMOKYRS      NACCTBI     DIABETES  ...  \
# count  1354.000000  1354.000000  1354.000000  1354.000000  1354.000000  ...
# mean      0.631462     0.952733     9.754801     0.127031     0.192762  ...
# std       0.482586     0.212289    14.351222     0.333131     0.432160  ...
# ...

# %% [markdown]
# TASK-4B: Please provide the visual illustrations of the dataset that will demonstrate the insightful distributions with respect to the target column (CDRGLOB: the level of the Alzheimer Disease -AD)

# %%
data.corr()["SEX"].sort_values().head().plot(kind="bar")

# %%
data.corr()["SEX"].sort_values().tail().plot(kind="bar")

# %%
sbn.countplot(data["CDRGLOB"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sbn.scatterplot(data["CDRGLOB"],data["SMOKYRS"],alpha=0.7)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sbn.scatterplot(data["CDRGLOB"],data["NACCBMI"],alpha=0.7)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sbn.boxenplot(data["CDRGLOB"],data["NACCBMI"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# TASK-4C: Please provide a correlation analysis between two different variables/features and argue for the analysis outputs

# %%
data_CDRGLOB=pd.DataFrame(data["CDRGLOB"])

# %%
data_CDRGLOB.head()
# Out:
#    CDRGLOB
# 0        0
# 1        2
# 2        0
# 3        0
# 4        1

# %%
data_CDRGLOB["EDUC"]=pd.DataFrame(data["EDUC"])
data_CDRGLOB["SMOKYRS"]=pd.DataFrame(data["SMOKYRS"])
data_CDRGLOB["HIPPOVOL"]=pd.DataFrame(data["HIPPOVOL"])

# %%
data_CDRGLOB
# Out:
#       CDRGLOB  EDUC  SMOKYRS  HIPPOVOL
# 0           0    18        0    6.9900
# 1           2    11        0    5.8700
# 2           0    16       10    6.4400
# 3           0    14        0    6.9100
# 4           1    16       50    5.8463
# ...       ...   ...      ...       ...
# 1349        1    20        0    7.5416
# 1350        2    16        0    5.3301
# 1351        0    14        0    6.2400
# 1352        0    20       25    7.4100
# 1353        0    14       10    6.0800
#
# [1354 rows x 4 columns]

# %%
data_CDRGLOB.corr()
# Out:
#            CDRGLOB      EDUC   SMOKYRS  HIPPOVOL
# CDRGLOB   1.000000 -0.140977  0.052314 -0.449069
# EDUC     -0.140977  1.000000 -0.102343  0.144993
# SMOKYRS   0.052314 -0.102343  1.000000 -0.048213
# HIPPOVOL -0.449069  0.144993 -0.048213  1.000000

# %%
data_CDRGLOB.corr()["CDRGLOB"].sort_values().plot(kind="bar")

# %% [markdown]
# TASK-4D: Please provide several pivot tables for insightful illustrations both via tables and figures.

# %%
Cut= pd.qcut(data["RSUPFRM"], 5)
data.pivot_table("SEX", index="CDRGLOB", columns=Cut)
# Out:
# RSUPFRM  (0.901, 1.928]  (1.928, 2.121]  (2.121, 2.263]  (2.263, 2.428]  \
# CDRGLOB
# 0              1.571429        1.648148        1.647059        1.714286
# 1              1.467742        1.518868        1.441441        1.556818
# 2              1.457627        1.431818        1.354839        1.529412
# 3              1.388889        1.500000        1.125000        1.600000
#
# RSUPFRM  (2.428, 4.06]
# CDRGLOB
# 0             1.691489
# 1             1.626866
# 2             1.428571
# 3             2.000000

# %%
data.pivot_table("SEX", index="CDRGLOB", columns=Cut, aggfunc="count")
# Out:
# RSUPFRM  (0.901, 1.928]  (1.928, 2.121]  (2.121, 2.263]  (2.263, 2.428]  \
# CDRGLOB
# 0                    70             108             119             161
# 1                   124             106             111              88
# 2                    59              44              31              17
# 3                    18              14               8               5
#
# RSUPFRM  (2.428, 4.06]
# CDRGLOB
# 0                  188
# 1                   67
# 2                   14
# 3                    2

# %%
data.pivot_table("EDUC", index=["HIPPOVOL"], columns=Cut).plot(kind="bar")
plt.show()

# %% [markdown]
# yukardaki karmaşayı azaltacak bir yöntem bulamadım
